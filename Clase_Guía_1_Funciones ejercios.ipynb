# %% [markdown]
# # Clase Funciones Viernes 16/08/24

# %% [markdown]
# ## Gráfico de funciones

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# importamos pyplot de matplotlib y numpy
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Se genera una tabla de datos usando numpy a la que
# se aplicará la función dada en el ejemplo, se toma la variable independiente x entre 0 y 6
# y los elementos de la tabla se separaran en 0,01.
#
# Para cada elemento x, se aplicó la función. Luego se arreglan los coeficientes de los ejes, se agrega un título al gráfico, títulos de los ejes y una grilla.

# %%
#Variable independiente x entre 0 y 6.
x = np.arange(0, 6, 0.01)
# para cada elemento, se aplicará la función
y = 120*x+2000
# le pedimos a matplotlib que genere un gráfico
plt.plot(x, y)
# cuyos ejes van de 0 a 6 en la variable x, de 0 a 2800 en la variable y
plt.axis([0, 6, 0, 2800])
# con un título de eje x
plt.xlabel('Energía utilizada ({kWh})')
# título de eje y
plt.ylabel('Costo para usuario ($)')
# titulo del gráfico
plt.title('Costo para el usuario según uso de energía')
# se pide mostrar una grilla para facilitar la lectura
plt.grid(True)
# Finalmente, que muestre el gráfico
plt.show()

# %% [markdown]
# # Ejercicios Guía 1: Funciones

# %% [markdown]
# ## Ejemplos:

# %% [markdown]
# ### Problema 1 (Problemas de la Sección)

# %% [markdown]
# P1. La altura promedio $f(x)$, en centímetros, de un niño durante su primer año de vida se puede determinar
# mediante la función $f(x) = 23x+48$, donde x es el tiempo transcurrido, en meses, desde que nace.
#
# a) Defina la variable dependiente e independiente, indicando unidad de medida.

# %% [markdown]
# Variable dependiente f(x):LA altura promedio (centimetros)
# Variable independiente x: Tiempo transcurrido (meses)

# %% [markdown]
# b) Escriba el dominio de la función y el dominio contextualizado.

# %% [markdown]
# Dominio de la funcion : Funcion lineal -> Domf = R
# Dominio Contextualizado:
# Durante su primer año de vida -> Domf = [0,12] meses

# %% [markdown]
# c) Determine e interprete $f(6)$ y $f(8)$.

# %%
def f(x):
    f =(2/3)* x + 48
    return f
print (f'f(6)={f(6)}')
print(f'Trasncurrido 6 mese el niño medira 186 cn')
ocho = (f'f(8)={f(8):.1f}')
print (ocho)
print(f'Transcurrido 8 meses el niño medira {ocho}   cm')
# Out:
# f(6)=52.0
# Trasncurrido 6 mese el niño medira 186 cn
# f(8)=53.3
# Transcurrido 8 meses el niño medira f(8)=53.3   cm

# %% [markdown]
# d) Si un niño mide 50 cm, ¿cuántos meses de vida tiene?

# %%
def f(x):
    f = (3/2 )*x - 72 
    return f
print(f'f(50)={f(50):.1f}')
# Out:
# f(50)=3.0

# %% [markdown]
# e) ¿Es posible calcular la edad de un niño si su estatura es de 68 cm?

# %%
NO es posible , porque un niño no se puede calcular edad

# %% [markdown]
# f) Grafique, utilizando la biblioteca matplotlib, la función $f(x)$.

# %%
# importamos pyplot de matplotlib y numpy
import matplotlib.pyplot as plt
import numpy as np

#Variable independiente x entre 0 y 6.
x = np.arange(0, 12, 0.01)
# para cada elemento, se aplicará la función
y = (2/3)*x+48
# le pedimos a matplotlib que genere un gráfico
plt.plot(x, y)
# cuyos ejes van de 0 a 6 en la variable x, de 0 a 2800 en la variable y
plt.axis([0, 12, 0, 60])
# con un título de eje x
plt.xlabel('Tiempo transcurrido en (meses)')
# título de eje y
plt.ylabel('Altura promedio (cm)')
# titulo del gráfico
plt.title('Relacion entre la altura promedio de un niño y el tiempo transcurrido')
# se pide mostrar una grilla para facilitar la lectura
plt.grid(True)
# Finalmente, que muestre el gráfico
plt.show()

# %% [markdown]
# ### Problema 2 (Problemas de la Sección)

# %% [markdown]
# P2. La regla de Young nos permite calcular la dosis en mg de medicamento que se debe administrar a niños
# desde 1 hasta 12 años de edad, conocida la dosis normal en adultos. Si la dosis normal de paracetamol para un adulto es de 500 mg, entonces la regla de Young dice que la función:
#
# $$ f(x)=\frac{500x}{x+12} $$
#
# Nos da la dosis para un niño, con x la edad del niño en años.
#
# a) Defina la variable dependiente e independiente, indicando unidad de medida.

# %% [markdown]
# Variable dependiente f(x) : Dosis (mg)
# Variable independiente x Edad del niño (años)

# %% [markdown]
# b) Escriba el dominio de la función y dominio contextualizado.

# %% [markdown]
# Dominio de la funcion : Funcion Racional -> Domx = R - {-12}
# Dominio Contextualizado:
# Domf = [1,12] años

# %% [markdown]
# c) ¿Es correcto administrar 512 mg de paracetamol a un niño de 10,5 años?

# %%
def f(x):
    f = (500*x)/ (x+12)
    return f
print (f'f(10.5)={f(10.5):.1f}')
# Out:
# f(10.5)=233.3

# %% [markdown]
# Si la edad del niño es de 10.5 años la dosis deberia ser de 233.mg, y no es correcto que sea de 512mg.

# %% [markdown]
# d) Determine e interprete $f(7)$.

# %% [markdown]
# e) ¿Cuánto medicamento se le debe administrar a un niño de 2 años con 6 meses?

# %% [markdown]
# f) Si a un niño se le administra 180 mg de paracetamol, ¿cuál es su edad?

# %% [markdown]
# g) Grafique, utilizando la biblioteca matplotlib, la función $f(x)$.

# %% [markdown]
# ### Problema 4

# %% [markdown]
# Como parte de un proyecto de mejora, en el año $2021$ se instaló un cable de fibra óptica que une España con EEUU. El cable tiene un largo de $6.600$ $km$ y fue colocado por un barco a una velocidad de $1,85$ $km/h$.
#
# 1.   Determine la forma algebraica de la función que permite determinar el largo del cable instalado (en km) a partir del tiempo transcurrido (en horas). Utilice la instrucción *def* para definir la función en *Python*.

# %% [markdown]
# 2.   Defina variable dependiente e independiente, indicando unidad de medida.

# %% [markdown]
# 3.   Determine el dominio contextualizado de la función.

# %% [markdown]
# 4.   Grafique la función utilizando la biblioteca *Matplotlib* considerando el dominio contextualizado.

# %% [markdown]
# 5.   ¿Cuántos metros de cable se instalaron al transcurrir $148$ horas? ¿Y transcurridas $2.300$ horas?

# %% [markdown]
# 6.   Si se han instalado $3.480$ kilometros de cable, ¿cuántas horas llevan de trabajo?

# %% [markdown]
# 7.   ¿Cuánto tiempo transcurrió para que se completara la obra?
